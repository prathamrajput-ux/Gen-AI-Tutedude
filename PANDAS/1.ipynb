# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
pd.Series(name = 'Praice of Grocery items',data=[40,50,60],index=['Braed','Milk','Butter'])
# Out:
# Braed     40
# Milk      50
# Butter    60
# Name: Praice of Grocery items, dtype: int64
