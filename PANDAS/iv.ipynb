# %%
import numpy as np
import pandas as pd

# %%
tren = pd.read_csv('data_1_col.csv')

# %%
tren.sum()
# Out:
# trending_date    26.26.0226.26.0226.26.0226.26.0226.26.0226.26....
# Unnamed: 1                                                     0.0
# Unnamed: 2                                                     0.0
# dtype: object

# %%
tren.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tren.median()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:14596, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   14592         >>> df.median(numeric_only=True)
#   14593         a   1.5
#   14594         dtype: float64
#   14595         """
# > 14596         result = super().median(
# ...

# %%
tren.max()
# Out:
# trending_date    26.26.02
# Unnamed: 1            NaN
# Unnamed: 2            NaN
# dtype: object

# %%
tren.max()
# Out:
# trending_date    26.26.02
# Unnamed: 1            NaN
# Unnamed: 2            NaN
# dtype: object

# %%
tren.min()
# Out:
# trending_date    26.26.02
# Unnamed: 1            NaN
# Unnamed: 2            NaN
# dtype: object

# %%
tren.describe()
# Out:
#        Unnamed: 1  Unnamed: 2
# count         0.0         0.0
# mean          NaN         NaN
# std           NaN         NaN
# min           NaN         NaN
# 25%           NaN         NaN
# 50%           NaN         NaN
# 75%           NaN         NaN
# max           NaN         NaN

# %%
tren[2:20:3]
# Out:
#    trending_date  Unnamed: 1  Unnamed: 2
# 2       26.26.02         NaN         NaN
# 5       26.26.02         NaN         NaN
# 8       26.26.02         NaN         NaN
# 11      26.26.02         NaN         NaN
# 14      26.26.02         NaN         NaN
# 17      26.26.02         NaN         NaN

# %%
hi
