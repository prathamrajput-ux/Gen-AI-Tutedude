# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_depression_dataset.csv')

# %%
df.sample(5)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 15146   76319    Male  23.0   Srinagar    Student                3.0
# 4946    24799    Male  22.0      Surat    Student                3.0
# 21742  109779    Male  26.0  Hyderabad    Student                2.0
# 1889     9695  Female  32.0      Patna    Student                3.0
# 7785    39129  Female  25.0     Indore    Student                2.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 15146            0.0  8.04                 4.0               0.0
# 4946             0.0  7.11                 3.0               0.0
# 21742            0.0  9.41                 4.0               0.0
# 1889             0.0  6.42                 4.0               0.0
# 7785             0.0  5.74                 5.0               0.0
#
#             Sleep Duration Dietary Habits  Degree  \
# 15146  'Less than 5 hours'       Moderate  B.Tech
# 4946   'Less than 5 hours'        Healthy     MSc
# 21742          '5-6 hours'        Healthy     BCA
# 1889           '7-8 hours'        Healthy     MCA
# 7785           '5-6 hours'        Healthy  B.Tech
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 15146                                   Yes               2.0
# 4946                                    Yes              10.0
# 21742                                    No               6.0
# 1889                                    Yes               0.0
# 7785                                     No               9.0
#
#       Financial Stress Family History of Mental Illness  Depression
# 15146              4.0                               No           1
# 4946               5.0                              Yes           1
# 21742              4.0                               No           0
# 1889               1.0                              Yes           0
# 7785               5.0                              Yes           0

# %%
df.sample()
# Out:
#            id Gender   Age    City Profession  Academic Pressure  \
# 25634  129196   Male  18.0  Rajkot    Student                2.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 25634            0.0  8.58                 3.0               0.0
#
#       Sleep Duration Dietary Habits      Degree  \
# 25634    '7-8 hours'       Moderate  'Class 12'
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 25634                                   Yes               8.0
#
#       Financial Stress Family History of Mental Illness  Depression
# 25634              3.0                               No           1

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='str')

# %%
x = ['a','b','c']
y = [10,30,20]

# %%
plt.plot(x,y)

# %%
data = df['Gender'].value_counts()

# %%
data
# Out:
# Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64

# %%
x = data.index
y = data.values

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y)
