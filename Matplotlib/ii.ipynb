# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_depression_dataset.csv')

# %%
df.sample(5)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 9684    48857    Male  34.0      Thane    Student                1.0
# 27014  136196    Male  18.0    Kolkata    Student                4.0
# 6406    32073  Female  19.0  Bangalore    Student                4.0
# 25344  127664  Female  20.0    Lucknow    Student                2.0
# 1838     9440    Male  23.0     Meerut    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9684             0.0  6.84                 3.0               0.0
# 27014            0.0  7.87                 1.0               0.0
# 6406             0.0  6.08                 5.0               0.0
# 25344            0.0  5.82                 5.0               0.0
# 1838             0.0  7.08                 5.0               0.0
#
#             Sleep Duration Dietary Habits      Degree  \
# 9684           '7-8 hours'        Healthy      M.Tech
# ...

# %%
df.sample()
# Out:
#            id Gender   Age      City Profession  Academic Pressure  \
# 23180  116879   Male  33.0  Srinagar    Student                2.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 23180            0.0  9.74                 4.0               0.0
#
#             Sleep Duration Dietary Habits Degree  \
# 23180  'Less than 5 hours'       Moderate    BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 23180                                    No              11.0
#
#       Financial Stress Family History of Mental Illness  Depression
# 23180              3.0                              Yes           0

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='str')

# %%
x = ['a','b','c']
y = [10,30,20]

# %%
plt.plot(x,y)

# %%
data = df['Gender'].value_counts()

# %%
data
# Out:
# Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64

# %%
x = data.index
y = data.values

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(10,5))
plt.title("Count of popul,ation gender wise")

plt.plot(x,y)
plt.ylabel("population")
plt.xlabel("Gender")
plt.grid()   
plt.show()
